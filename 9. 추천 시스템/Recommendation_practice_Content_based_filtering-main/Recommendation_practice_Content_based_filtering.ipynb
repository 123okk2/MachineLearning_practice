# %% [markdown]
# # 장르 속성을 이용한 영화 컨텐츠 기반 필터링

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

movies = pd.read_csv('./tmdb/tmdb_5000_movies.csv')
#data from https://www.kaggle.com/tmdb/tmdb-movie-metadata


print(movies.shape) #20개의 특성, 4803개의 레코드
movies.head(3)
# Out:
# (4803, 20)
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# ...

# %% [markdown]
# ## 주요한 칼럼만 추출해서 변경

# %%
movies_df = movies[['id', 'title', 'genres', 'vote_average', 'vote_count', 'popularity', 'keywords', 'overview']]
'''
id : 식별자
title : 제목
genres : 장르
vote_average : 평균 평점
vote_count : 평점 투표 수
popularity : 인기도
keywords : 영화에 대한 키워드
overview : 영화에 대한 개요
'''

#그런데 genres와 keywords가 리스트 내의 dict 형태로 되어있음.
#문자열을 분해해서 개별 장르와 키워드 추출
from ast import literal_eval

#문자열을 객체로 변환
movies_df['genres'] = movies_df['genres'].apply(literal_eval)
movies_df['keywords'] = movies_df['keywords'].apply(literal_eval)

#리스트(딕셔너리) 에서 객체만 빼내기
movies_df['genres'] = movies_df['genres'].apply(lambda x : [y['name'] for y in x])
movies_df['keywords'] = movies_df['keywords'].apply(lambda x : [y['name'] for y in x])
movies_df[['genres', 'keywords']][:1]

movies_df.head(3)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
#
#                                           genres  vote_average  vote_count  \
# 0  [Action, Adventure, Fantasy, Science Fiction]           7.2       11800
# 1                   [Adventure, Fantasy, Action]           6.9        4500
# 2                     [Action, Adventure, Crime]           6.3        4466
#
#    popularity                                           keywords  \
# 0  150.437577  [culture clash, future, space war, space colon...
# 1  139.082615  [ocean, drug abuse, exotic island, east india ...
# 2  107.376788  [spy, based on novel, secret agent, sequel, mi...
#
#                                             overview
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# ...

# %% [markdown]
# ## CountVectorizer를 통한 장르의 벡터화

# %%
from sklearn.feature_extraction.text import CountVectorizer

#벡터화를 위해 공백문자로 word 단위가 구분되는 문자열로 변환
movies_df['genres_literal'] = movies_df['genres'].apply(lambda x : (' ').join(x))
count_vect = CountVectorizer(min_df = 0, ngram_range=(1,2))
genre_mat = count_vect.fit_transform(movies_df['genres_literal'])
print(genre_mat.shape)
# Out:
# (4803, 276)

# %% [markdown]
# ## Cosine_similarity 를 통한 유사도 비교

# %%
from sklearn.metrics.pairwise import cosine_similarity

genre_sim = cosine_similarity(genre_mat, genre_mat)
print(genre_sim.shape)
print(genre_sim[:1])

#객체의 기준 행별로 비교 대상이 되는 행의 유사도 값이 높은 순으로 정렬
genre_sim = genre_sim.argsort()[:, ::-1]
print(genre_sim[:1])
# Out:
# (4803, 4803)
# [[1.         0.59628479 0.4472136  ... 0.         0.         0.        ]]
# [[   0 3494  813 ... 3038 3037 2401]]

# %% [markdown]
# ## 장르 콘텐츠 필터링을 이용한 영화 추천

# %% [markdown]
# ### 단순히 장르가 비슷한 영화 추천

# %%
def find_sim_movie(df, sorted_ind, title_name, top_n=10):
    #장르 유사도에 따라 영화를 추천해주는 함수
    # 인자로 입력된 movies_df DataFrame에서 'title' 컬럼이 입력된 title_name 값인 DataFrame추출
    title_movie = df[df['title'] == title_name]
    
    # title_named을 가진 DataFrame의 index 객체를 ndarray로 반환하고 
    # sorted_ind 인자로 입력된 genre_sim_sorted_ind 객체에서 유사도 순으로 top_n 개의 index 추출
    title_index = title_movie.index.values
    similar_indexes = sorted_ind[title_index, :(top_n)]
    
    # 추출된 top_n index들 출력. top_n index는 2차원 데이터 임. 
    #dataframe에서 index로 사용하기 위해서 1차원 array로 변경
    print(similar_indexes)
    similar_indexes = similar_indexes.reshape(-1)
    
    return df.iloc[similar_indexes]


#대부와 장르별로 유사한 영화 10개 추천
similar_movies = find_sim_movie(movies_df, genre_sim, 'The Godfather',10)
similar_movies[['title', 'vote_average']]
# Out:
# [[2731 1243 3636 1946 2640 4065 1847 4217  883 3866]]
#                                                title  vote_average
# 2731                          The Godfather: Part II           8.3
# 1243                                    Mean Streets           7.2
# 3636                                   Light Sleeper           5.7
# 1946  The Bad Lieutenant: Port of Call - New Orleans           6.0
# 2640         Things to Do in Denver When You're Dead           6.7
# 4065                                      Mi America           0.0
# 1847                                      GoodFellas           8.2
# 4217                                            Kids           6.8
# 883                              Catch Me If You Can           7.7
# 3866                                     City of God           8.1

# %% [markdown]
# ### 좀 더 많은 후보군을 선정한 뒤 영화의 평점에 따라 필터링해서 최종 추천

# %%
#높은 평점들 확인
movies_df[['title','vote_average','vote_count']].sort_values('vote_average', ascending=False)[:10]
# Out:
#                          title  vote_average  vote_count
# 3519          Stiff Upper Lips          10.0           1
# 4247     Me You and Five Bucks          10.0           2
# 4045     Dancer, Texas Pop. 81          10.0           1
# 4662            Little Big Top          10.0           1
# 3992                 Sardaarji           9.5           2
# 2386            One Man's Hero           9.3           2
# 2970        There Goes My Baby           8.5           2
# 1881  The Shawshank Redemption           8.5        8205
# 2796     The Prisoner of Zenda           8.4          11
# 3337             The Godfather           8.4        5893

# %% [markdown]
# 이름도 들어본 적 없는 영화들이 높은 평점을 차지하고 있음을 확인.
# 모두 평가 횟수가 작은데, 이와 같은 왜곡된 평점 데이터를 피하기 위해 평가 횟수에 가중치가 부여된 가중 평점을 사용.
#
# 가중 평점 (Weighted Raring) = (v/(v+m))*R + (m/(n+m)) * C
#
# v : 투표 수
# m : 평점을 부여하기 위한 최소 투표 수
# R : 개별 영화에 대한 평균 평점
# C : 전체 영화에 대한 평균 평점

# %%
#v는 vote_count ,R은 vote_average
#C는 movies_df['vote_average'].mean()
#m은 이제 정해야 하는데, 높으면 평점 투표 횟수가 많은 영화에 더 많은 가중 평점이 부여된다.
#이번 실습에서는 상위 60%에 해당하는 횟수를 기준으로 선정

C= movies_df['vote_average'].mean()
m = movies_df['vote_count'].quantile(0.6)

def weighted_vote_average(record):
    v = record['vote_count']
    R = record['vote_average']
    
    return ( (v/(v+m)) * R ) + ( (m/(m+v)) * C )   

movies_df['weighted_vote'] = movies_df.apply(weighted_vote_average, axis=1)

#평점이 높은 10개 다시 추출
movies_df[['title','vote_average','weighted_vote','vote_count']].sort_values('weighted_vote', ascending=False)[:10]
# Out:
#                          title  vote_average  weighted_vote  vote_count
# 1881  The Shawshank Redemption           8.5       8.396052        8205
# 3337             The Godfather           8.4       8.263591        5893
# 662                 Fight Club           8.3       8.216455        9413
# 3232              Pulp Fiction           8.3       8.207102        8428
# 65             The Dark Knight           8.2       8.136930       12002
# 1818          Schindler's List           8.3       8.126069        4329
# 3865                  Whiplash           8.3       8.123248        4254
# 809               Forrest Gump           8.2       8.105954        7927
# 2294             Spirited Away           8.3       8.105867        3840
# 2731    The Godfather: Part II           8.3       8.079586        3338

# %%
def find_sim_movie(df, sorted_ind, title_name, top_n=10):
    #함수를 높은 평점의 영화만 추천하도록 변경
    title_movie = df[df['title'] == title_name]
    title_index = title_movie.index.values
    
    # top_n의 2배에 해당하는 쟝르 유사성이 높은 index 추출 
    similar_indexes = sorted_ind[title_index, :(top_n*2)]
    similar_indexes = similar_indexes.reshape(-1)
    # 기준 영화 index는 제외
    similar_indexes = similar_indexes[similar_indexes != title_index]
    
    # top_n의 2배에 해당하는 후보군에서 weighted_vote 높은 순으로 top_n 만큼 추출 
    return df.iloc[similar_indexes].sort_values('weighted_vote', ascending=False)[:top_n]

#다시 한 번 대부로 영화 추천
similar_movies = find_sim_movie(movies_df, genre_sim, 'The Godfather',10)
similar_movies[['title', 'vote_average', 'weighted_vote']]
# Out:
#                             title  vote_average  weighted_vote
# 2731       The Godfather: Part II           8.3       8.079586
# 1847                   GoodFellas           8.2       7.976937
# 3866                  City of God           8.1       7.759693
# 1663  Once Upon a Time in America           8.2       7.657811
# 883           Catch Me If You Can           7.7       7.557097
# 281             American Gangster           7.4       7.141396
# 4041              This Is England           7.4       6.739664
# 1149              American Hustle           6.8       6.717525
# 1243                 Mean Streets           7.2       6.626569
# 2839                     Rounders           6.9       6.530427
